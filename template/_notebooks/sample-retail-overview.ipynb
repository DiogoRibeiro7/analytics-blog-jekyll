# %% [markdown]
# # Retail Performance Overview
# This sample notebook demonstrates how to publish notebooks with the Datalog theme.

# %%
import pandas as pd
df = pd.read_csv('../datasets/sample-retail-metrics.csv')
df.groupby('store_id')['revenue'].sum()
