# %% [markdown]
# # Notebook: Exploratory Data Snapshot

# %% [markdown]
# This notebook demonstrates how DataLog renders `.ipynb` files using the `notebook` layout.

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
data = pd.DataFrame({
    'feature': np.linspace(0, 1, 5),
    'value': np.random.randn(5).round(3)
})
data

# %% [markdown]
# You can include inline equations like $e^{i\pi} + 1 = 0$ and narrative commentary to explain findings.
